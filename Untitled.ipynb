# %%
import requests 
res = requests.get("https://www.1111.com.tw/job-bank/job-index.asp?si=1&c0=100900&d0=170100&fs=1&page=1")

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n   <head>\r\n      <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n      <title>台中市工具機加工工作職缺/工作機會列表(第1頁/20筆)│找工作就上1111人力銀行</title>\r\n      <meta charset="utf-8" />\r\n      \r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" />\r\n    \r\n      <meta http-equiv="Content-Language" content="zh-tw" />\r\n      <meta name="robots" content="index,follow" />\r\n      <meta name="title" content="台中市工具機加工工作職缺/工作機會列表(第1頁/20筆)│找工作就上1111人力銀行" />\r\n      <meta name="keywords" content="工作,職缺,台中市,工具機加工" />\r\n      <meta name="description" content="【台中市工具機加工工作職缺/工作機會列表】CNC銑床人員(需有經驗)、CNC應用工程師、CNC車床-中班技術員(中科廠)、CNC電腦車床技術師、銑床組立人員、大夜班_CNC銑床作業員、CAM工程師(北區，該職缺需先至中區受訓))、CNC電腦車床技術員、CNC車床-早班技術員(中科廠)。1111人力銀行網羅眾多知名企業職缺，可依照您想要的工作地區、工作職務、工作產業，推薦您精準適合的職缺。想找更多的相關職缺，就快上1111人力銀行搜尋。" />\r\n      <meta property="og:title" content="台中市工具機加工工作職缺/工作機會列表(第1頁/20筆)│找工作就上1111人力銀行" />
# ...

# %%
import bs4
print (bs4.__file__)
urls= ['https://www.1111.com.tw/job-bank/job-index.asp?si=1&c0=100900&d0=170100&fs=1&page={}.html'.format(str(i)) for i in range(1,24)]
# Out:
# C:\Users\moc026\Anaconda3\lib\site-packages\bs4\__init__.py
